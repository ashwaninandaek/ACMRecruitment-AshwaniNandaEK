# %%
import pandas as pd
#Load the dataset using Pandas
path=r"C:\Users\Kishore\Downloads\StudentsPerformance.csv"
df=pd.read_csv(path)
#Handle missing values (if any)
print(df.isna().sum())
print(df.dropna().sum())
df[df.isna().any(axis=1)]
print(df.fillna("True"))
print(df)
#Remove duplicate records
df_cleaned = df.drop_duplicates()
print(df)
#Verify that the cleaned dataset contains no duplicates or unintended missing values.
print(df.duplicated().sum())
print(df.isna().sum())
print(df.isna().sum().sum())
#Save the cleaned dataset as cleaned_students_performance.csv.
df.to_csv('cleaned_students_performance.csv', index=False)
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64
# gender                         femalefemalefemalemalemalefemalefemalemalemale...
# race/ethnicity                 group Bgroup Cgroup Bgroup Agroup Cgroup Bgrou...
# parental level of education    bachelor's degreesome collegemaster's degreeas...
# lunch                          standardstandardstandardfree/reducedstandardst...
# test preparation course        nonecompletednonenonenonenonecompletednonecomp...
# math score                                                                 66089
# reading score                                                              69169
# writing score                                                              68054
# dtype: object
# ...
